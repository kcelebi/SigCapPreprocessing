# %%
import json
import os
import pandas as pd
import gmaps
import matplotlib.pyplot as plt
gmaps.configure(api_key='AIzaSyCtZYWpMyGTqwYhiJ-focuI20YbB461u1M')
from scripts.preprocessing import *

# %%
data = getData('data_01_28_22_2')

# %%
time_diff = []
keys = sorted(data['id'], key = lambda x: data['time_stamp'][x])

# %%
plt.plot(time_diff)
plt.plot([0,100],[2,2])
plt.legend(labels = ['deltaT', 'y=2'])
plt.xlabel('Measurement Index')
plt.ylabel('TimeStamp Difference')
plt.show()

# %%
fig = gmaps.figure(map_type = 'HYBRID')
heatmap_layer = gmaps.heatmap_layer(getLocationDF(data))
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
